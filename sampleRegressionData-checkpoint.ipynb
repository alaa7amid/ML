# %%
#import library
from sklearn.datasets import make_regression

# %%
#load regression data
x,y=make_regression(n_samples=100,n_features=50,shuffle=True)

# %%
# x data
print("x data is:\n",x[:10])
print("x shape is:\n",x.shape)
# Out:
# x data is:
#  [[-6.30046823e-01 -9.36708952e-02 -1.28270966e-01 -8.43040400e-01
#    2.34090923e+00 -2.59485362e-01 -7.07885303e-01 -1.28112297e+00
#   -5.99333801e-01 -1.42266097e+00  2.06751694e-01  9.31862089e-02
#   -1.42862526e-01  3.56525618e-01  1.22976407e+00 -4.89534499e-01
#   -2.21410466e-01  3.69542422e-01  2.45419789e-01 -3.39492505e-03
#   -2.52951004e-01  2.56620847e-01  8.05540640e-02 -1.54139324e+00
#    1.10498599e+00 -5.77721541e-01 -2.49440607e-01 -8.62680064e-01
#    3.43970044e-01  2.98445955e-01 -1.22505113e+00  2.25406608e+00
#   -1.70205964e+00 -1.67240314e+00 -1.15366961e+00 -7.32789428e-02
#   -6.39637878e-01  4.68685379e-01 -1.56395008e+00 -5.32998747e-01
#    1.24796526e+00 -1.70223097e-01  1.91047175e-01 -1.59054883e+00
#   -7.15946538e-01 -5.19868959e-01  5.05530809e-01 -3.38132598e-01
#   -1.03406501e+00  1.66190371e+00]
#  [ 1.15249834e-01  8.89527497e-01  2.61992409e+00  9.90063500e-01
# ...

# %%
# y data 
print("y data is:\n",y[:10])
print("y shape is:\n",y.shape)
# Out:
# y data is:
#  [-153.58008814  143.97354851   40.34211621  173.04172492  -46.69607425
#   132.1273045   -31.66834654 -118.78532432   79.14243298 -382.15703612]
# y shape is:
#  (100,)
