# %%
#impoer library
from sklearn.datasets import make_classification

# %%
#load clasificatin data
x,y=make_classification(n_samples=100,n_features=50,shuffle=True)

# %%
#x data
print("x data is:\n",x[:10])
print("x shape is:\n",x.shape)
# Out:
# x data is:
#  [[-8.00807492e-01 -1.13920961e+00 -7.74116409e-01  9.80241818e-01
#   -2.64095911e-01  1.03458013e+00  3.86360583e-01 -3.79239052e-01
#    1.26545111e+00 -2.69014346e-01 -1.48646241e-01 -8.78299449e-01
#    3.11732540e-01 -3.24399149e-02  5.26095920e-02  3.62226201e-01
#   -1.19547637e+00 -4.33064542e-01 -3.80203615e-01 -1.50790478e+00
#   -4.10130802e-01  1.34204267e-01 -1.26565582e+00  2.47894154e-01
#    1.05982682e+00  5.07691225e-02  6.64400453e-02  1.15885747e+00
#    1.65236462e-01 -3.94445130e-01  9.23084328e-01 -6.87658680e-01
#   -6.82672380e-01 -8.72066580e-01  7.26583357e-01 -2.95760857e-01
#   -4.20636711e-01  5.12256929e-01  1.90911657e+00  2.13250062e-01
#   -7.61169264e-01 -1.62714353e+00  3.21363141e-01  1.63444663e-01
#   -1.59946193e+00 -1.66285669e-02  1.02320222e-01 -1.29778011e-01
#   -1.78622127e+00 -7.75686565e-01]
#  [ 7.37195351e-01  3.83377178e-01  3.99174127e-01  4.46485814e-01
# ...

# %%
# y data 
print("y data is:\n",y[:10])
print("y shape is:\n",y.shape)
# Out:
# y data is:
#  [0 1 1 1 0 0 1 0 1 1]
# y shape is:
#  (100,)
